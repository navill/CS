# %% [markdown]
# # tuple
# ## immutable 객체이다
# ## 인덱싱으로 접근은 가능하지만
# ## 요소의 값 변경은 불가능하다
# ## list보다 빠르고 효율적이다

# %%
tu=(1, 2, 3, 4)

# %%
tu2=()

# %%
tu
# Out:
# (1, 2, 3, 4)

# %%
tu2
# Out:
# ()

# %%
tu[2]
# Out:
# 3

# %%
tu[2]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cfaf37a707df> in <module>
# ----> 1 tu[2]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
dir(tu)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']
